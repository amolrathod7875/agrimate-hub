# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Agri_sahayak_02\backend\9ef84268-d588-465a-a308-a864a43d0070.csv")

# %%
df['State'].unique().tolist()
# Out:
# ['Himachal Pradesh',
#  'Punjab',
#  'Kerala',
#  'West Bengal',
#  'Odisha',
#  'Uttar Pradesh',
#  'Gujarat',
#  'Nagaland',
#  'Uttarakhand',
#  'Haryana']

# %%
df['District'].unique().tolist()
# Out:
# ['Kangra',
#  'Mohali',
#  'Alappuzha',
#  'Ernakulam',
#  'Kollam',
#  'Kottayam',
#  'Amritsar',
#  'Ropar (Rupnagar)',
#  'Bankura',
#  'Sundergarh',
#  'Malappuram',
#  'Kozhikode(Calicut)',
#  'Tarntaran',
#  'Idukki',
#  'Dhenkanal',
#  'Hooghly',
#  'Ghazipur',
#  'Amreli',
#  'Dimapur',
#  'Moga',
#  'Dehradoon',
#  'Mau(Maunathbhanjan)',
#  'Hathras',
#  'Gurgaon',
#  'Thiruvananthapuram',
#  'Narmada',
#  'Bargarh',
#  'Faridkot',
#  'Balrampur']

# %%
mask = df['District'].str.contains('Kangra', case=False, na=False) | df['Market'].str.contains('pune', case=False, na=False)
mask.any(), df.loc[mask]
# Out:
# (True,
#                  State District           Market               Commodity  \
#  0    Himachal Pradesh   Kangra     SMY Palampur    Indian Colza(Sarson)
#  2    Himachal Pradesh   Kangra  SMY Jaisinghpur               Mashrooms
#  8    Himachal Pradesh   Kangra     SMY Palampur             Pomegranate
#  15   Himachal Pradesh   Kangra  SMY Jaisinghpur                 Raddish
#  17   Himachal Pradesh   Kangra  SMY Jaisinghpur        Cucumbar(Kheera)
#  27   Himachal Pradesh   Kangra  SMY Jaisinghpur                  Carrot
#  31   Himachal Pradesh   Kangra  SMY Jaisinghpur           Ginger(Green)
#  49   Himachal Pradesh   Kangra  SMY Jaisinghpur             Cauliflower
#  60   Himachal Pradesh   Kangra     SMY Palampur                   Onion
#  64   Himachal Pradesh   Kangra  SMY Jaisinghpur                  Banana
#  70   Himachal Pradesh   Kangra     SMY Palampur                   Lemon
#  72   Himachal Pradesh   Kangra  SMY Jaisinghpur  French Beans(Frasbean)
# ...
